# %%
import tarfile
from IPython.display import Image
from pathlib import Path

# %% [markdown]
# Copying training and validation data to /mnt/data

# %%
# !gcloud storage cp gs://dsgt-clef-fungiclef-2024/DF20-train_val.tar.gz /mnt/data
# Out:
# Copying gs://dsgt-clef-fungiclef-2024/DF20-train_val.tar.gz to file:///mnt/data/DF20-train_val.tar.gz
#   Completed files 1/1 | 73.5GiB/73.5GiB | 99.7MiB/s
#
# Average throughput: 387.8MiB/s

# %% [markdown]
# Extracting - with error

# %%
# open file 
file = tarfile.open('/mnt/data/DF20-train_val.tar.gz') 
  
# extracting file 
file.extractall('/mnt/data/') 
  
file.close()
# Out:
# ---------------------------------------------------------------------------
# EOFError                                  Traceback (most recent call last)
# Cell In[5], line 5
#       2 file = tarfile.open('/mnt/data/DF20-train_val.tar.gz')
#       4 # extracting file
# ----> 5 file.extractall('/mnt/data/')
#       7 file.close()
#
# File /usr/lib/python3.10/tarfile.py:2257, in TarFile.extractall(self, path, members, numeric_owner, filter)
#    2252     if tarinfo.isdir():
#    2253         # For directories, delay setting attributes until later,
#    2254         # since permissions can interfere with extraction and
#    2255         # extracting contents can reset mtime.
#    2256         directories.append(tarinfo)
# -> 2257     self._extract_one(tarinfo, path, set_attrs=not tarinfo.isdir(),
#    2258                       numeric_owner=numeric_owner)
#    2260 # Reverse sort directories.
#    2261 directories.sort(key=lambda a: a.name, reverse=True)
#
# File /usr/lib/python3.10/tarfile.py:2320, in TarFile._extract_one(self, tarinfo, path, set_attrs, numeric_owner)
#    2317 self._check("r")
#    2319 try:
# -> 2320     self._extract_member(tarinfo, os.path.join(path, tarinfo.name),
#    2321                          set_attrs=set_attrs,
#    2322                          numeric_owner=numeric_owner)
#    2323 except OSError as e:
#    2324     self._handle_fatal_error(e)
#
# File /usr/lib/python3.10/tarfile.py:2403, in TarFile._extract_member(self, tarinfo, targetpath, set_attrs, numeric_owner)
#    2400     self._dbg(1, tarinfo.name)
#    2402 if tarinfo.isreg():
# -> 2403     self.makefile(tarinfo, targetpath)
#    2404 elif tarinfo.isdir():
#    2405     self.makedir(tarinfo, targetpath)
#
# File /usr/lib/python3.10/tarfile.py:2456, in TarFile.makefile(self, tarinfo, targetpath)
#    2454     target.truncate()
#    2455 else:
# -> 2456     copyfileobj(source, target, tarinfo.size, ReadError, bufsize)
#
# File /usr/lib/python3.10/tarfile.py:252, in copyfileobj(src, dst, length, exception, bufsize)
#     250 blocks, remainder = divmod(length, bufsize)
#     251 for b in range(blocks):
# --> 252     buf = src.read(bufsize)
#     253     if len(buf) < bufsize:
#     254         raise exception("unexpected end of data")
#
# File /usr/lib/python3.10/gzip.py:301, in GzipFile.read(self, size)
#     299     import errno
#     300     raise OSError(errno.EBADF, "read() on write-only GzipFile object")
# --> 301 return self._buffer.read(size)
#
# File /usr/lib/python3.10/_compression.py:68, in DecompressReader.readinto(self, b)
#      66 def readinto(self, b):
#      67     with memoryview(b) as view, view.cast("B") as byte_view:
# ---> 68         data = self.read(len(byte_view))
#      69         byte_view[:len(data)] = data
#      70     return len(data)
#
# File /usr/lib/python3.10/gzip.py:507, in _GzipReader.read(self, size)
#     505         break
#     506     if buf == b"":
# --> 507         raise EOFError("Compressed file ended before the "
#     508                        "end-of-stream marker was reached")
#     510 self._add_read_data( uncompress )
#     511 self._pos += len(uncompress)
#
# EOFError: Compressed file ended before the end-of-stream marker was reached

# %% [markdown]
# Example

# %%
img_path = Path('/mnt/data/DF20')
img_file = Path('2238339784-86423.JPG')

# prompt: view the jpg image from img_filename
Image(filename=img_path / img_file, width=500, height=500)

# %%
img_file = Path('2430666980-196975.JPG')

Image(filename=img_path / img_file, width=500, height=500)
